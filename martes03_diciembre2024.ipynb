# %% [markdown]
# <a href="https://colab.research.google.com/github/maribelalay18/-Artificial-Intelligence/blob/main/martes03_diciembre2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
movies = pd.read_csv('/content/movis.csv')
ratings= pd.read_csv('/content/ratings.csv')
tags= pd.read_csv('/content/tags.csv')

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
tags.head(2)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0

# %%
print(ratings.index)
print(tags.index)
print(movies.index)
# Out:
# RangeIndex(start=0, stop=100836, step=1)
# RangeIndex(start=0, stop=3683, step=1)
# RangeIndex(start=0, stop=9742, step=1)

# %%
print(ratings.columns)
print(tags.columns)
print(movies.columns)
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')

# %% [markdown]
# analisis estadistico descriptivo

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0

# %%
print(ratings ['rating'].describe())
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
print(ratings['rating'].modem())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-0391a61dc02b> in <cell line: 1>()
# ----> 1 print(ratings['rating'].modem())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'modem'

# %% [markdown]
# correlation: relacion entre variables osea si ambas crecen su relacion es proporcional y si una crece y la otra no es indirectamente proporcional

# %%
ratings. shape
# Out:
# (100836, 3)

# %% [markdown]
# shape para ver la forma, muestras y variables

# %%
tags.shape
# Out:
# (3683, 3)

# %%
movies.shape
# Out:
# (9742, 3)

# %% [markdown]
# como identificar las muestras que no tengan información

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %% [markdown]
# para visualizar el nivel de popularidad

# %%
# %matplotlib inline
ratings.hist(column='rating',figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %% [markdown]
# existe un promedio de 4 el nivel de popularidad de películas

# %%
tags.head(10)
# Out:
#    userId  movieId                tag
# 0       2    60756              funny
# 1       2    60756    Highly quotable
# 2       2    60756       will ferrell
# 3       2    89774       Boxing story
# 4       2    89774                MMA
# 5       2    89774          Tom Hardy
# 6       2   106782              drugs
# 7       2   106782  Leonardo DiCaprio
# 8       2   106782    Martin Scorsese
# 9       7    48516       way too long

# %% [markdown]
# imprimir etiquetas ùnicas

# %%
etiquetas_unicas = tags['tag'].unique()
print(etiquetas_unicas)
# Out:
# ['funny' 'Highly quotable' 'will ferrell' ... 'gun fu' 'heroic bloodshed'
#  'Heroic Bloodshed']

# %% [markdown]
# cuantas etiquetas únicas hay?

# %%
print(len(etiquetas_unicas))
# Out:
# 1589

# %% [markdown]
# imprimir movies las 3 primeras muestras

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
tags.head(3)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable
# 2       2    60756     will ferrell

# %%
conteo_etiquetas = tags['tag'].value_counts()
print(conteo_etiquetas)
# Out:
# tag
# In Netflix queue     131
# atmospheric           36
# thought-provoking     24
# superhero             24
# funny                 23
#                     ...
# small towns            1
# In Your Eyes           1
# Lloyd Dobbler          1
# weak plot              1
# Heroic Bloodshed       1
# Name: count, Length: 1589, dtype: int64

# %%
tags_count[:10].plot(kind='bar',figsize=(5,10))
# Out:
# <Axes: xlabel='tag'>

# %% [markdown]
# imprimir la base de datos ratings realizar un filtro de peliculas que tengan mayor popularidad de 4 a 5

# %%
filtro_popularidad = ratings[(ratings['rating'] >= 4) & (ratings['rating'] <= 5)]
print(filtro_popularidad)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100830     610   166528     4.0
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
#
# [48580 rows x 3 columns]

# %%
peliculas_populares = ratings[(ratings['rating'] >= 4) & (ratings['rating'] <= 5)]
print(peliculas_populares)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100830     610   166528     4.0
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
#
# [48580 rows x 3 columns]

# %%
is_highly_rated = ratings['rating']>=4.0
print(type(is_highly_rated))
print(is_highly_rated.shape)
print(is_highly_rated.head(10))
# Out:
# <class 'pandas.core.series.Series'>
# (100836,)
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# Name: rating, dtype: bool

# %%
is_highly_rated.head(3)
# Out:
# 0    True
# 1    True
# 2    True
# Name: rating, dtype: bool

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %% [markdown]
# filtrar las peliculas que extraiga las caractiristicas que cumpla con la palabra animation

# %%
peliculas_animacion = movies[movies['genres'].str.contains("animation", case=False, na=False)]
caracteristicas_animacion = peliculas_animacion[['movieId', 'title', 'genres']]
print(caracteristicas_animacion)
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 12         13                                       Balto (1995)
# 44         48                                  Pocahontas (1995)
# 205       239                              Goofy Movie, A (1995)
# 272       313                          Swan Princess, The (1994)
# ...       ...                                                ...
# 9733   193567  anohana: The Flower We Saw That Day - The Movi...
# 9735   193573            Love Live! The School Idol Movie (2015)
# 9737   193581          Black Butler: Book of the Atlantic (2017)
# 9738   193583                       No Game No Life: Zero (2017)
# 9740   193587                Bungo Stray Dogs: Dead Apple (2018)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 12                   Adventure|Animation|Children
# ...

# %%
num_muestras = movies.shape[0]
print(num_muestras)
# Out:
# 9742
